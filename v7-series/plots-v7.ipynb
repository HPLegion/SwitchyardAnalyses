# %%
import os
import altair as alt
alt.enable_mime_rendering()
import pandas as pd

# %%
DATA = pd.DataFrame()
for filename in os.listdir():
    if "emit_v7a" in filename or "emit_v7_base"in filename:
        frame = pd.read_csv(filename)
        frame["modelname"] = filename[5:-4]
        DATA = DATA.append(frame, ignore_index=True)

# %%
print(DATA.head(5))
print(DATA.tail(5))
# Out:
#    Unnamed: 0  sourceID  sourceName  x_offset  y_offset  x_emittance  \
# 0           0  16777222   x_-15_y_0     -15.0       0.0     1.699806
# 1           1  16777229   x_-15_y_5     -15.0       5.0     1.664591
# 2           2  16777236  x_-15_y_10     -15.0      10.0     1.687151
# 3           3  16777243  x_-15_y_15     -15.0      15.0     1.762783
# 4           4  16777220   x_-10_y_0     -10.0       0.0     1.596168
#
#    y_emittance  x_norm_emittance  y_norm_emittance  losses   relbeta  \
# 0     1.572440          0.003924          0.003630       0  0.002308
# 1     1.593141          0.003843          0.003678       0  0.002308
# 2     1.595804          0.003895          0.003684       0  0.002308
# 3     1.665882          0.004069          0.003846       0  0.002308
# 4     1.553038          0.003685          0.003585       0  0.002308
#
#    x_emittance_rel  y_emittance_rel modelname
# 0         1.048529         1.000117  v7a_base
# 1         1.044894         0.999662  v7a_base
# 2         1.043312         0.999448  v7a_base
# 3         1.054812         1.002409  v7a_base
# 4         1.002538         1.000278  v7a_base
#      Unnamed: 0  sourceID sourceName  x_offset  y_offset  x_emittance  \
# 107          23  16777240  x_10_y_15      10.0      15.0     1.689204
# 108          24  16777221   x_15_y_0      15.0       0.0     1.726248
# 109          25  16777228   x_15_y_5      15.0       5.0     1.722440
# 110          26  16777235  x_15_y_10      15.0      10.0     1.750781
# 111          27  16777242  x_15_y_15      15.0      15.0     1.686347
#
#      y_emittance  x_norm_emittance  y_norm_emittance  losses   relbeta  \
# 107     1.545609          0.003899          0.003568       0  0.002308
# 108     1.581400          0.003985          0.003651       0  0.002308
# 109     1.486661          0.003976          0.003432       1  0.002308
# 110     1.638086          0.004042          0.003781       0  0.002308
# 111     1.670865          0.003893          0.003857       0  0.002308
#
#      x_emittance_rel  y_emittance_rel modelname
# 107         1.073954         1.022677   v7_base
# 108         1.151963         1.002065   v7_base
# 109         1.095816         1.000747   v7_base
# 110         1.078904         1.013829   v7_base
# 111         1.113178         1.052455   v7_base

# %%
alt.Chart(DATA).mark_line().encode(
    column="modelname",
    color='y_offset:N',
    x='x_offset',
    #y='x_emittance_rel',
    y=alt.Y("x_emittance_rel", scale=alt.Scale(domain=(1,1.2), zero=False))
)

# %%
alt.Chart(DATA).mark_line().encode(
    column="modelname",
    color='y_offset:N',
    x='x_offset',
    #y='y_emittance_rel',
    y=alt.Y("y_emittance_rel", scale=alt.Scale(domain=(1,1.2), zero=False))
)

# %%
alt.Chart(DATA).mark_line().encode(
    column="modelname",
    color='y_offset:N',
    x='x_offset',
    y='losses',
)
